# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from lenstronomy.LensModel.lens_model import LensModel
from lenstronomy.LensModel.Solver.lens_equation_solver import LensEquationSolver
import lenstronomy.Plots.output_plots as lens_plot

# %%
lens_model_list = ['POINT_MASS']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_sis = {'theta_E': 1, 'center_x': 0., 'center_y': 0.}
kwargs_lens = [kwargs_sis]
f, axex = plt.subplots(1, 2, figsize=(10, 5), sharex=False, sharey=False)
beta_ra, beta_dec = .8, .8
lens_plot.lens_model_plot(axex[0], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)
beta_ra, beta_dec = 0, 0
lens_plot.lens_model_plot(axex[1], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)
f.show()
# Out:
# /global/u1/j/jimenago/StrongLensing/lenstronomy/lenstronomy/Plots/output_plots.py:94: RuntimeWarning: divide by zero encountered in log10
#   im = ax.matshow(np.log10(kappa_result), origin='lower', extent=[0, _frame_size, 0, _frame_size], cmap='Greys',
# /global/u1/j/jimenago/StrongLensing/lenstronomy/lenstronomy/LensModel/lens_model.py:189: RuntimeWarning: divide by zero encountered in true_divide
#   return 1./det_A  # attention, if dividing by zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-caf8252e8df3> in <module>
#       7 lens_plot.lens_model_plot(axex[0], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)
#       8 beta_ra, beta_dec = 0, 0
# ...

# %%
lens_model_list = ['POINT_MASS']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_sis = {'theta_E': 1, 'center_x': 0., 'center_y': 0.}
kwargs_lens = [kwargs_sis]
beta_ra, beta_dec = 1.5, 1.5
print(beta_ra)
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
    print(beta_ra)
f.show()
# Out:
# 1.5
# 1.425
# 1.35
# 1.2750000000000001
# 1.2000000000000002
# 1.1250000000000002

# %%
lens_model_list = ['POINT_MASS']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_sis = {'theta_E': 1, 'center_x': 0., 'center_y': 0.}
kwargs_lens = [kwargs_sis]
beta_ra, beta_dec = 1.5, 1.5
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
print(beta_ra, beta_dec)
# Out:
# 5.273559366969494e-16 5.273559366969494e-16

# %%
lens_model_list = ['SIS']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_sis = {'theta_E': 1, 'center_x': 0., 'center_y': 0.}
kwargs_lens = [kwargs_sis]
beta_ra, beta_dec = 1.5, 1.5
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    beta_ra, beta_dec = beta_ra-.075, beta_dec-.075
f.show()

# %%
lens_model_list = ['SPEP']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_spep = {'theta_E': 1, 'e1': 0.05, 'e2': 0.05, 'gamma': 2., 'center_x': 0, 'center_y': 0}
kwargs_lens = [kwargs_spep]
theta_ra, theta_dec = .9, .9
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()

# %%
lens_model_list = ['SPEP', 'SHEAR']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_spep = {'theta_E': 1, 'e1': 0.05, 'e2': 0.05, 'gamma': 2., 'center_x': 0, 'center_y': 0}
kwargs_shear = {'e1': 0.2, 'e2': 0.0}
kwargs_lens = [kwargs_spep, kwargs_shear]
theta_ra, theta_dec = .9, .9
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.02, theta_dec-.02
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.02, theta_dec-.02
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.02, theta_dec-.02
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.02, theta_dec-.02
f.show()

# %%
lens_model_list = ['SPEP', 'SIS']
lensModel = LensModel(lens_model_list=lens_model_list)
kwargs_spep = {'theta_E': .9, 'e1': 0.05, 'e2': 0.05, 'gamma': 2., 'center_x': 0.1, 'center_y': 0}
#kwargs_shear = {'e1': 0.05, 'e2': 0.0}
kwargs_sis = {'theta_E': 0.1, 'center_x': 1., 'center_y': -0.1}
kwargs_lens = [kwargs_spep, kwargs_sis]
theta_ra, theta_dec = 1.8, 1.8
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()
f, axex = plt.subplots(1, 5, figsize=(15, 15), sharex=False, sharey=False)
for i in range(0,5):
    beta_ra, beta_dec = lensModel.ray_shooting(theta_ra, theta_dec, kwargs_lens)
    lens_plot.lens_model_plot(axex[i], lensModel=lensModel, kwargs_lens=kwargs_lens, sourcePos_x=beta_ra, sourcePos_y=beta_dec, point_source=True, with_caustics=True)    
    theta_ra, theta_dec = theta_ra-.01, theta_dec-.01
f.show()
